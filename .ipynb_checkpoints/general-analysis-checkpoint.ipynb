# %% [markdown]
# ## Trending YouTube Videos
#
# This analysis has been done on data version 440 (10/17/2021). Please extract the content inside **./data**

# %%
import json
import pandas as pd
import re

# %% [markdown]
# ### Selecting a region to analyze
# Below, you can set the region to analyze and the line display limit.
# For this analysis, we will only be looking at data from the US.

# %%
# "Data is included for the IN, US, GB, DE, CA, FR, RU, BR, MX, KR, and JP regions 
# (India, USA, Great Britain, Germany, Canada, France, Russia, Brazil, Mexico, South Korea, and, Japan respectively)"
# please enter region in two letter format (like first line) and in quotation on variable region
region = "US"

#display_limit = 1000

# %% [markdown]
# The code below checks for existence of data, along with some initializations and error checking.

# %%
from os import listdir

data_files_location = {}
categories = {}

for f in listdir('./data'):
    if f.endswith('.json'):
        temp = json.load(open(f'./data/{f}'))
        for i in temp['items']:
            categories[i['id']] = i['snippet']['title']
    if f.endswith('.csv'):
        data_files_location[f[:2]] = f'./data/{f}'

if not categories:
    raise FileNotFoundError('can not locate any json category files')
    
if not data_files_location:
    raise FileNotFoundError('no CSV data files are located')

# %% [markdown]
# ### Clean up the DataFrame
# - Load and assign CSV files onto variables with Pandas
# - Remove unnecessary columns
# - Map the categories from the .json file to 'categoryId' in DataFrame as a new column, labeled 'videoCategory'

# %%
data = pd.read_csv(data_files_location[region])
# drop unnecessary columns
data.drop(['thumbnail_link', 'comments_disabled', 'ratings_disabled'], inplace=True, axis=1)
# map categories to a new column 
data['videoCategory'] = data['categoryId'].astype(str).map(categories)

data
# Out:
#           video_id                                              title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 87586  FdzPV69i4Aw                  Great Idea 💡 #shorts #tips #short
# 87587  40_wdosHJaQ  I Was In The Funniest Minecraft Competition Wi...
# 87588  cNG1QNQPlNE      Summoner Changes | FFXIV Endwalker Media Tour
# 87589  iYTK_1Sq8ZQ       Reaper Overview | FFXIV Endwalker Media Tour
# 87590  OP-CQdYR71s              I Designed Custom Minecraft Bosses...
#
#                 publishedAt                 channelId   channelTitle  \
# 0      2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis
# 1      2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends
# 2      2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye
# 3      2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL
# 4      2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate
# ...                     ...                       ...            ...
# 87586  2021-10-12T12:00:12Z  UCGLDtG2tl0uG8P0eNstbLUA      Tool_Tips
# 87587  2021-10-12T00:15:10Z  UCFbZ2e9IrPejOdp8wsKUxvA      QuackiTwo
# 87588  2021-10-13T12:00:29Z  UCQjKMGUEzBmEHltb1OIMLUg      Larryzaur
# 87589  2021-10-13T12:00:32Z  UCQjKMGUEzBmEHltb1OIMLUg      Larryzaur
# 87590  2021-10-10T21:58:05Z  UCojEXrCBzO-cP2N5YlRcrWw  Daniel Krafft
#
#        categoryId         trending_date  \
# 0              22  2020-08-12T00:00:00Z
# 1              20  2020-08-12T00:00:00Z
# 2              24  2020-08-12T00:00:00Z
# 3              10  2020-08-12T00:00:00Z
# 4              26  2020-08-12T00:00:00Z
# ...           ...                   ...
# 87586          26  2021-10-17T00:00:00Z
# 87587          24  2021-10-17T00:00:00Z
# 87588          20  2021-10-17T00:00:00Z
# 87589          20  2021-10-17T00:00:00Z
# 87590          27  2021-10-17T00:00:00Z
#
#                                                     tags  view_count   likes  \
# 0      brawadis|prank|basketball|skits|ghost|funny vi...     1514614  156908
# 1      Apex Legends|Apex Legends characters|new Apex ...     2381688  146739
# 2      jacksepticeye|funny|funny meme|memes|jacksepti...     2038853  353787
# 3      xxl freshman|xxl freshmen|2020 xxl freshman|20...      496771   23251
# 4      The LaBrant Family|DIY|Interior Design|Makeove...     1123889   45802
# ...                                                  ...         ...     ...
# 87586                                             [None]     3241407   27687
# 87587  Quackity|Quackitwo|Quackity Second Channel|Qua...      425760   48882
# 87588  ffxiv|final fantasy xiv|ff14|final fantasy 14|...      203634    7065
# 87589  ffxiv|final fantasy xiv|ff14|final fantasy 14|...      210207    6884
# 87590  minecraft|blender|minecraft art|minecraft mobs...     2163981   95225
#
#        dislikes  comment_count  \
# 0          5855          35313
# 1          2794          16549
# 2          2628          40221
# 3          1856           7647
# 4           964           2196
# ...         ...            ...
# 87586      9037            937
# 87587       215           1238
# 87588        52            754
# 87589        43            540
# 87590       921           3964
#
#                                              description   videoCategory
# 0      SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...  People & Blogs
# 1      While running her own modding shop, Ramya Pare...          Gaming
# 2      I left youtube for a month and this is what ha...   Entertainment
# 3      Subscribe to XXL → http://bit.ly/subscribe-xxl...           Music
# 4      Transforming The LaBrant Family's empty white ...   Howto & Style
# ...                                                  ...             ...
# 87586                                                NaN   Howto & Style
# 87587  STREAMED LIVE ON TWITCH: https://www.twitch.tv...   Entertainment
# 87588  Endwalker Media Tour Playlist ► https://www.yo...          Gaming
# 87589  Endwalker Media Tour Playlist ► https://www.yo...          Gaming
# 87590  Minekrafft 5Start creating on CORE today: http...       Education
#
# [87591 rows x 14 columns]

# %% [markdown]
# ### Basic Analysis of Dataset
#
# This dataset contains:
# - a total of 87,591 entries
# - 15,180 unique videos
# - 4,252 unique channel IDs
#
# Many videos and channels have duplicate entries in this dataset, as they can stay in top-trending for multiple days.

# %%
# number of unique videos in dataset
print(f"Unique videos: {data.video_id.nunique()}")
# number of unique channel IDs in dataset
print(f"Unique channel IDs: {data.channelId.nunique()}")
# number of unique channel titles in dataset
print(f"Unique channel titles: {data.channelTitle.nunique()}")
# Out:
# Unique videos: 15180
# Unique channel IDs: 4252
# Unique channel titles: 4310

# %% [markdown]
# #### Categories in Trending
# Here, we take a look at the amount of videos that have trended in each category. The entertainment category has the most trending videos, and the nonprofits & activism category has the fewest.

# %%
category_count = data.videoCategory.value_counts()
category_count
# Out:
# Entertainment            17615
# Music                    16552
# Gaming                   14458
# Sports                    9574
# People & Blogs            7524
# Comedy                    4721
# Film & Animation          3364
# News & Politics           3315
# Science & Technology      3199
# Howto & Style             2933
# Education                 1870
# Autos & Vehicles          1556
# Pets & Animals             474
# Travel & Events            351
# Nonprofits & Activism       85
# Name: videoCategory, dtype: int64

# %% [markdown]
# #### Appearance of Videos & Channels in Trending
# Below, we analyze the number of times videos and channels have appeared in trending.

# %%
# number of times a video has been in top-trending videos
video_trend_count = data[['video_id', 'title']].value_counts().to_frame('count')

video_trend_count
# Out:
#                                                                 count
# video_id    title
# hdmx71UjBXs Turn into orbeez - Tutorial #Shorts                    36
# aONT7atzqfw Floyd Mayweather vs Logan Paul: Fight goes the ...     35
# mcUpeaSX8BE Israeli Iron Dome filmed intercepting rockets f...     34
# wY6UyatwVTA India claim stunning series win, end Australia'...     34
# vrRfBmMWpLY Golden Buzzer: 9-Year-Old Victory Brinker Makes...     33
# ...                                                               ...
# cAtazIk1IYw How To Make a Curried Egg Sandwich                      1
# cC9aarA1Mhg BTS (방탄소년단) PERMISSION TO DANCE ON STAGE Offici...      1
# cDTayGZNRdg Chucky TV Series Season 1 Premiere | Full Episo...      1
# cINpXjiZiTk LAKERS at ROCKETS | FULL GAME HIGHLIGHTS | Sept...      1
# UuZlU2BzpV4 AGUERO FAIRYTALE AT THE ETIHAD | Man City 5-0 E...      1
#
# [15556 rows x 1 columns]

# %%
vid_eq_one = (video_trend_count['count'] == 1).value_counts()
vid_eq_one
print(f"{vid_eq_one[0]} videos have trended more than once and {vid_eq_one[1]} have trended only once")
# Out:
# 15006 videos have trended more than once and 550 have trended only once

# %% [markdown]
# Some channel IDs are associated with more than one channel title. Below, is a DataFrame that combines the multiple channel titles onto a single row in the 'channelTitle' column, matching its respective channel ID. Then shows the count of every channel according to channel ID.<br><br>
# For this analysis, 'channel' will refer to the channel ID.

# %%
# combine titles with the same channel ID
comb_titles = data.groupby(['channelId'])
channel_trend_count = pd.DataFrame({'channelTitle(s)': comb_titles['channelTitle'].unique(), 'count': data['channelId'].value_counts()})
# number of times a channel has been in top-trending videos
channel_trend_count.sort_values('count', ascending=False)
# Out:
#                                 channelTitle(s)  count
# UCWJ2lWNubArHWmf3FIHbfcQ                  [NBA]    550
# UCDVYQ4Zhbm3S2dlz7P1GBDg                  [NFL]    528
# UCpB959t8iPrxQWj7G6n0ctQ         [SSSniperWolf]    458
# UCIPPMRA040LQr5QPyJEbmXA       [MrBeast Gaming]    377
# UCke6I9N4KfC968-yRcd5YRg              [SSundee]    336
# ...                                         ...    ...
# UC4Llz_FxdMEU0iWO4aG_Xjg             [Roadshow]      1
# UCHmv6QMb4xerJ8Tt5UBHjaw            [MegaToons]      1
# UCulu1KUYJ_2OBDouc_d-cUA      [Mat Watson Cars]      1
# UCLCCG11dS-HyB3up3OCRV_w            [Tivi Gunz]      1
# UC1JOnWZrVWKzX3UMdpnvuMg  [Paradox Interactive]      1
#
# [4252 rows x 2 columns]

# %%
ch_eq_one = (channel_trend_count['count'] == 1).value_counts()

print(f"{ch_eq_one[0]} channels have multiple trend videos and {ch_eq_one[1]} have only one")
# Out:
# 4216 channels have multiple trend videos and 36 have only one

# %% [markdown]
# #### Filter Out Duplicate Video Entries
# - Filter out the duplicate entries to obtain the most recent number of view counts, likes, dislikes, and comment counts.

# %%
# obtain the most recent entry with the highest view count
final = data.sort_values('view_count', ascending=False).drop_duplicates(['video_id'])
final
# Out:
#           video_id                                              title  \
# 56374  WMweEpGlu_U                   BTS (방탄소년단) 'Butter' Official MV
# 3358   gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# 73564  hdmx71UjBXs                Turn into orbeez - Tutorial #Shorts
# 4980   vRXZj0DzXIA    BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V
# 68979  CuklIb9d3fI      BTS (방탄소년단) 'Permission to Dance' Official MV
# ...            ...                                                ...
# 15289  r7nYQXsxJdU          HBCU Homecoming 2020: Meet Me On The Yard
# 65049  kmk5vciFbek  Demi Lovato performs their greatest hits this ...
# 74964  Hb3rmh-_FMw            Introducing the shorter side of YouTube
# 73992  HcSwBJY7Xew  Watch The Weeknd and create short videos on th...
# 48995  mCY4b6GGkb4               The Funeral of The Duke of Edinburgh
#
#                 publishedAt                 channelId       channelTitle  \
# 56374  2021-05-21T03:46:13Z  UC3IZKseVpdzPSBaWxBxundA        HYBE LABELS
# 3358   2020-08-21T03:58:10Z  UC3IZKseVpdzPSBaWxBxundA     Big Hit Labels
# 73564  2021-07-03T04:04:57Z  UCt8z2S30Wl-GQEluFVM8NUw             FFUNTV
# 4980   2020-08-28T04:00:11Z  UCOmHUn--16B90oW2L6FRR3A          BLACKPINK
# 68979  2021-07-09T03:59:12Z  UC3IZKseVpdzPSBaWxBxundA        HYBE LABELS
# ...                     ...                       ...                ...
# 15289  2020-10-25T01:40:31Z  UCqVDpXKLmKeBU_yyt_QkItQ  YouTube Originals
# 65049  2021-06-26T00:07:19Z  UCZkURf9tDolFOeuw_4RD7XQ        Demi Lovato
# 74964  2021-08-10T15:04:25Z  UCBR8-60-B28hp2BmDPdntcQ            YouTube
# 73992  2021-08-10T15:08:22Z  UCBR8-60-B28hp2BmDPdntcQ            YouTube
# 48995  2021-04-17T14:56:38Z  UCTkC3Jt91QkqNAE4FGWkEIQ   The Royal Family
#
#        categoryId         trending_date  \
# 56374          10  2021-05-30T00:00:00Z
# 3358           10  2020-08-28T00:00:00Z
# 73564          24  2021-08-08T00:00:00Z
# 4980           10  2020-09-05T00:00:00Z
# 68979          10  2021-07-16T00:00:00Z
# ...           ...                   ...
# 15289          24  2020-10-27T00:00:00Z
# 65049          24  2021-06-27T00:00:00Z
# 74964          27  2021-08-15T00:00:00Z
# 73992          27  2021-08-11T00:00:00Z
# 48995          22  2021-04-18T00:00:00Z
#
#                                                     tags  view_count  \
# 56374                    BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   264407389
# 3358                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   232649205
# 73564                                             [None]   206202284
# 4980   YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   184778248
# 68979                       HYBE|HYBE LABELS|하이브|하이브레이블즈   156482499
# ...                                                  ...         ...
# 15289  2 CHAINZ|DESI BANKS|LIONEL RICHIE |LANCE GROSS...           0
# 65049  Pride|Pride 2021|YouTube Pride|YouTube Pride 2...           0
# 74964                                             [None]           0
# 73992                                             [None]           0
# 48995                                             [None]           0
#
#           likes  dislikes  comment_count  \
# 56374  16021534    150989        6738537
# 3358   15735533    714194        6065230
# 73564   6840430    240769           2826
# 4980   11795670    879354        2735997
# 68979  12117314    102132        2781218
# ...         ...       ...            ...
# 15289      4257       384            240
# 65049         0         0            138
# 74964     22585      1636              0
# 73992     50071      7256              0
# 48995         0         0              0
#
#                                              description   videoCategory
# 56374  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...           Music
# 3358   BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...           Music
# 73564  Turn into orbeez - Tutorial #ShortsHey guys! W...   Entertainment
# 4980   BLACKPINK - ‘Ice Cream (with Selena Gomez)’Com...           Music
# 68979  BTS (방탄소년단) 'Permission to Dance' Official MVC...           Music
# ...                                                  ...             ...
# 15289  HBCU Homecoming 2020 is going down! We welcome...   Entertainment
# 65049  On June 25, celebrate Pride 2021 with Demi Lov...   Entertainment
# 74964  *****EPILEPSY WARNING ********Watch and create...       Education
# 73992                                                NaN       Education
# 48995  The Funeral procession and service for His Roy...  People & Blogs
#
# [15180 rows x 14 columns]

# %% [markdown]
# ### Title Analysis

# %% [markdown]
# #### Title Length
# - The number of words in the top trending video titles have a range of 1 to 23
# - The average title in top-trending videos has 8 words.
#
# There are videos in the US dataset that contain foreign characters in the title, such as "BTS (방탄소년단) 'Butter' Official MV". For this analysis, "(방탄소년단)" is considered one word. Therefore, this title contains a total of 5 words.

# %% [markdown]
# Title lengths of trending videos sorted by videos with most view counts

# %%
# videos with the the most view counts and their title lengths
title_word_count = pd.DataFrame({'word_count': final['title'].str.lower().str.replace('[^\w\s]', '', regex=True).str.split().apply(len)})
title_word_count.loc[:, ['title']] = final[['title']]
title_word_count
# Out:
#        word_count                                              title
# 56374           5                   BTS (방탄소년단) 'Butter' Official MV
# 3358            5                 BTS (방탄소년단) 'Dynamite' Official MV
# 73564           5                Turn into orbeez - Tutorial #Shorts
# 4980            7    BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V
# 68979           7      BTS (방탄소년단) 'Permission to Dance' Official MV
# ...           ...                                                ...
# 15289           8          HBCU Homecoming 2020: Meet Me On The Yard
# 65049          12  Demi Lovato performs their greatest hits this ...
# 74964           6            Introducing the shorter side of YouTube
# 73992          11  Watch The Weeknd and create short videos on th...
# 48995           7               The Funeral of The Duke of Edinburgh
#
# [15180 rows x 2 columns]

# %% [markdown]
# Sorting by the highest to lowest counts, we see that most trending videos have a title length of 7 words, and the fewest have 23 words.

# %%
# title lengths and the number of videos w/ that title length
word_count = final['title'].str.split().apply(len).value_counts().to_frame('count')
word_count = word_count.rename_axis(index='title_length')
word_count.reset_index(inplace=True)
word_count
# Out:
#     title_length  count
# 0              7   1879
# 1              8   1688
# 2              9   1635
# 3              6   1575
# 4             10   1286
# 5              5   1158
# 6             11   1131
# 7             12    852
# 8              4    741
# 9             13    721
# 10            14    515
# 11             3    425
# 12            15    390
# 13            16    358
# 14            17    251
# 15             2    184
# 16            18    175
# 17            19     98
# 18             1     52
# 19            20     41
# 20            21     13
# 21            22      7
# 22            23      5

# %%
average = (title_word_count['word_count'].sum()) / len(title_word_count)
print(f'The average title length in trending videos is {round(average)} words.')
# Out:
# The average title length in trending videos is 8 words.

# %% [markdown]
# #### Common Words & Phrases

# %%
def phrasing(arr, k = 1):
    if len(arr) > k < 1:
        raise ValueError('Invalid array input or k value')
    ret = []
    for i in range(len(arr)+1-k):
        extract = arr[i:i+k]
        ret.append(' '.join(extract))
    return ret

def title_analysis(arr, w = 1):
    ret = {}
    for i in arr:
        t = i.lower()
        temp = phrasing(re.findall(r"\w+'*\w+", t), w)
        for k in temp:
            try:
                ret[k] += 1
            except KeyError:
                ret[k] = 1
    return ret

# %%
# prints dictionary in sorted order
def print_dict_sort(arr, re=False, limit=-1):
    count = 0
    # code from: https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
    sorted_list = sorted(arr.items(), key=lambda item: item[1], reverse=re)
    d = dict(sorted_list)
    return d

# %%
# most common single words in titles
# using DF that filters out multiple video entries
one_word = print_dict_sort(title_analysis(final['title']), True)
one_word
# Out:
# {'the': 3482,
#  'official': 1998,
#  'video': 1759,
#  'to': 1575,
#  'in': 1412,
#  'of': 999,
#  'vs': 867,
#  'and': 846,
#  'on': 824,
#  'my': 769,
#  'with': 758,
#  'highlights': 734,
#  'music': 638,
#  '2021': 634,
#  'trailer': 624,
#  'is': 602,
#  'you': 600,
#  '2020': 585,
#  'for': 570,
#  'minecraft': 551,
#  'new': 538,
#  'at': 532,
#  'game': 480,
#  'ft': 434,
#  'shorts': 399,
#  'first': 394,
#  'how': 348,
#  'from': 328,
#  'us': 316,
#  'this': 315,
#  'season': 308,
#  'lil': 300,
#  'it': 294,
#  'live': 290,
#  'full': 290,
#  'but': 280,
#  'me': 279,
#  'feat': 271,
#  'we': 267,
#  'what': 257,
#  'day': 253,
#  'among': 246,
#  'by': 231,
#  '000': 229,
#  'nba': 229,
#  'audio': 223,
#  'episode': 218,
#  'your': 212,
#  'out': 208,
#  'world': 205,
#  'why': 203,
#  'life': 202,
#  'after': 200,
#  'fortnite': 199,
#  'that': 197,
#  '10': 196,
#  'oficial': 194,
#  'baby': 193,
#  'up': 189,
#  'are': 187,
#  'challenge': 180,
#  'best': 179,
#  'every': 179,
#  'our': 179,
#  'bts': 178,
#  'sports': 176,
#  'all': 176,
#  'part': 175,
#  'teaser': 171,
#  'night': 168,
#  'nfl': 166,
#  'week': 166,
#  'house': 163,
#  'show': 162,
#  'can': 158,
#  'as': 157,
#  'update': 153,
#  '100': 152,
#  'no': 152,
#  'reveal': 152,
#  'time': 149,
#  'reacts': 149,
#  'if': 148,
#  'ever': 144,
#  'home': 143,
#  'about': 143,
#  'an': 141,
#  'dream': 140,
#  'one': 139,
#  'be': 136,
#  'not': 135,
#  'more': 135,
#  'his': 134,
#  'real': 133,
#  'got': 131,
#  'when': 129,
#  '12': 127,
#  'ufc': 126,
#  'iphone': 125,
#  'final': 125,
#  'big': 124,
#  'over': 124,
#  'review': 124,
#  'off': 122,
#  'league': 121,
#  "i'm": 121,
#  'ep': 117,
#  'most': 116,
#  'was': 116,
#  'series': 115,
#  'win': 115,
#  'el': 114,
#  'friday': 114,
#  'man': 113,
#  'like': 113,
#  'news': 113,
#  'get': 113,
#  'fight': 112,
#  'remix': 111,
#  '21': 111,
#  'mv': 109,
#  'into': 109,
#  'la': 109,
#  'days': 109,
#  'made': 109,
#  'love': 108,
#  'have': 108,
#  'reaction': 107,
#  'things': 106,
#  'back': 105,
#  'black': 104,
#  'tour': 101,
#  'car': 100,
#  'paul': 99,
#  'theory': 97,
#  'lakers': 97,
#  'make': 96,
#  'people': 96,
#  'he': 96,
#  'never': 96,
#  'battle': 96,
#  'lyric': 95,
#  'take': 95,
#  'mod': 94,
#  'so': 93,
#  'animation': 93,
#  'funkin': 92,
#  'test': 91,
#  'will': 91,
#  '13': 90,
#  'who': 90,
#  'family': 90,
#  'her': 90,
#  'bad': 89,
#  'open': 89,
#  'watch': 89,
#  'pro': 89,
#  'super': 88,
#  'extended': 88,
#  'do': 87,
#  '20': 87,
#  'breakdown': 87,
#  'awards': 85,
#  'or': 85,
#  'food': 85,
#  'song': 84,
#  'everything': 84,
#  'friends': 84,
#  'legends': 84,
#  'event': 83,
#  'wins': 83,
#  'happened': 83,
#  'try': 83,
#  'performance': 82,
#  'nbc': 82,
#  'inside': 82,
#  'gets': 82,
#  'movie': 82,
#  'star': 82,
#  'only': 79,
#  'last': 79,
#  'war': 79,
#  'city': 79,
#  "don't": 78,
#  "it's": 78,
#  'cbs': 78,
#  'scenes': 77,
#  'look': 77,
#  'de': 77,
#  'story': 77,
#  'year': 76,
#  'go': 75,
#  'apple': 75,
#  'bought': 75,
#  'they': 75,
#  'play': 74,
#  'down': 74,
#  'dead': 74,
#  '24': 73,
#  '14': 73,
#  'their': 72,
#  'here': 72,
#  'goes': 71,
#  '30': 71,
#  'king': 71,
#  'hot': 70,
#  'james': 70,
#  'disney': 70,
#  '15': 70,
#  'gameplay': 70,
#  "can't": 69,
#  'hours': 69,
#  'again': 69,
#  'react': 69,
#  'before': 69,
#  'stephen': 69,
#  'broke': 68,
#  'justin': 68,
#  'exclusive': 68,
#  'trump': 68,
#  'young': 67,
#  'did': 67,
#  'pregnant': 67,
#  'behind': 66,
#  'free': 66,
#  'now': 66,
#  'know': 66,
#  'making': 66,
#  'top': 66,
#  '17': 66,
#  'announcement': 66,
#  'dance': 65,
#  'durk': 65,
#  'max': 65,
#  'explained': 65,
#  'old': 64,
#  'see': 64,
#  'secret': 64,
#  'tiktok': 63,
#  'cold': 63,
#  'interview': 63,
#  'face': 63,
#  '11': 63,
#  '방탄소년단': 62,
#  'insane': 62,
#  'easter': 62,
#  'death': 62,
#  'really': 62,
#  'round': 62,
#  'talk': 61,
#  'hardcore': 61,
#  'ps5': 61,
#  'birthday': 60,
#  'good': 60,
#  "world's": 60,
#  'school': 60,
#  'special': 60,
#  'marvel': 60,
#  'just': 60,
#  'build': 59,
#  'call': 59,
#  'next': 59,
#  'cat': 59,
#  'hermitcraft': 59,
#  'way': 58,
#  'joe': 58,
#  'games': 58,
#  'ball': 58,
#  'united': 58,
#  'boy': 58,
#  'espn': 58,
#  'los': 57,
#  'unboxing': 57,
#  'fc': 57,
#  'money': 56,
#  'bieber': 56,
#  'beat': 56,
#  'friend': 56,
#  'survived': 56,
#  'makeup': 56,
#  'jake': 56,
#  'has': 56,
#  'nas': 55,
#  'film': 55,
#  'dog': 55,
#  'trying': 55,
#  'cup': 55,
#  'than': 54,
#  'finally': 54,
#  'guys': 54,
#  'ucl': 54,
#  'crazy': 52,
#  'youtube': 52,
#  'snl': 52,
#  'ultimate': 52,
#  'royale': 52,
#  'race': 52,
#  'barcelona': 52,
#  'polo': 51,
#  'wild': 51,
#  'building': 51,
#  'actually': 51,
#  'found': 51,
#  'john': 51,
#  'dynamite': 50,
#  'kids': 50,
#  'harry': 50,
#  'high': 50,
#  'christmas': 50,
#  'kid': 50,
#  'apex': 50,
#  'getting': 50,
#  'ice': 49,
#  'mystery': 49,
#  'stars': 49,
#  'too': 49,
#  'prince': 49,
#  'years': 49,
#  'september': 49,
#  'tv': 49,
#  'custom': 49,
#  'smp': 49,
#  'wrong': 49,
#  'manchester': 49,
#  'tokyo': 49,
#  'end': 48,
#  'need': 48,
#  'netflix': 48,
#  'edition': 48,
#  'say': 48,
#  'while': 48,
#  'cooking': 48,
#  'ending': 47,
#  "d'amelio": 47,
#  'freestyle': 47,
#  'hacks': 47,
#  'chris': 47,
#  'minutes': 47,
#  'usa': 47,
#  '50': 46,
#  'shot': 46,
#  'president': 46,
#  'clash': 46,
#  'gold': 46,
#  'truth': 46,
#  'room': 46,
#  'worst': 46,
#  'tik': 46,
#  'post': 46,
#  'ariana': 45,
#  'biden': 45,
#  'better': 45,
#  'press': 45,
#  'halloween': 45,
#  'dixie': 45,
#  'meet': 45,
#  'skin': 45,
#  'history': 45,
#  'nets': 45,
#  'taylor': 44,
#  'makes': 44,
#  'emotional': 44,
#  'team': 44,
#  'twins': 44,
#  'fire': 44,
#  'guide': 44,
#  'moving': 44,
#  'eating': 43,
#  'billie': 43,
#  'power': 43,
#  'laugh': 43,
#  'tom': 43,
#  'does': 43,
#  'grand': 43,
#  'gta': 43,
#  'hit': 43,
#  'pokémon': 43,
#  '19': 43,
#  'clippers': 43,
#  'vlog': 43,
#  'eggs': 43,
#  'turn': 42,
#  'eilish': 42,
#  'grande': 42,
#  'fox': 42,
#  'am': 42,
#  'him': 42,
#  'introducing': 42,
#  '4k': 42,
#  '16': 42,
#  'album': 42,
#  'boyfriend': 42,
#  'work': 42,
#  'voice': 42,
#  'chapter': 42,
#  'mission': 42,
#  'kelly': 42,
#  "here's": 42,
#  'da': 41,
#  'lost': 41,
#  'party': 41,
#  'break': 41,
#  'squid': 41,
#  '18': 41,
#  'away': 41,
#  'rick': 41,
#  'white': 41,
#  'animated': 41,
#  'flight': 41,
#  'art': 41,
#  'nintendo': 41,
#  'roblox': 41,
#  'olympics': 41,
#  'against': 41,
#  'savage': 40,
#  'future': 40,
#  'red': 40,
#  'queen': 40,
#  'don': 40,
#  'launch': 40,
#  'scott': 40,
#  'met': 40,
#  'wars': 40,
#  'cole': 40,
#  'heat': 40,
#  'blackpink': 39,
#  'she': 39,
#  'monster': 39,
#  'coming': 39,
#  'space': 39,
#  'been': 39,
#  'different': 39,
#  '22': 39,
#  'ready': 39,
#  'surprising': 39,
#  'youngboy': 39,
#  'little': 39,
#  'slow': 39,
#  'faze': 39,
#  'premier': 39,
#  'gender': 39,
#  'warzone': 39,
#  'megan': 38,
#  'egg': 38,
#  'stop': 38,
#  'del': 38,
#  "we're": 38,
#  'stage': 38,
#  'xbox': 38,
#  'conor': 38,
#  'impact': 38,
#  'during': 38,
#  'machine': 38,
#  'state': 38,
#  'lebron': 38,
#  'match': 38,
#  'built': 38,
#  'girl': 37,
#  'fake': 37,
#  'right': 37,
#  'yo': 37,
#  'original': 37,
#  'without': 37,
#  'studios': 37,
#  'version': 37,
#  'were': 37,
#  'wwe': 37,
#  'switch': 37,
#  'mcgregor': 37,
#  'wings': 37,
#  'ios': 37,
#  'van': 37,
#  'loss': 37,
#  '2k22': 37,
#  'thee': 36,
#  'stallion': 36,
#  'park': 36,
#  'there': 36,
#  'giant': 36,
#  'hbo': 36,
#  'player': 36,
#  'light': 36,
#  'basketball': 36,
#  'opening': 36,
#  'pass': 36,
#  'champions': 36,
#  'conference': 36,
#  'viral': 36,
#  'collection': 36,
#  'undisputed': 36,
#  'girls': 35,
#  'twice': 35,
#  'stray': 35,
#  'weeknd': 35,
#  'towers': 35,
#  'doja': 35,
#  'shop': 35,
#  'let': 35,
#  'legend': 35,
#  'had': 35,
#  'mike': 35,
#  'water': 35,
#  'west': 35,
#  'tyson': 35,
#  'brown': 35,
#  'another': 35,
#  'israel': 35,
#  'ones': 35,
#  'august': 35,
#  'hurricane': 35,
#  'bucks': 35,
#  'funny': 34,
#  'name': 34,
#  'pop': 34,
#  'went': 34,
#  'jay': 34,
#  'item': 34,
#  'air': 34,
#  'sidemen': 34,
#  'fnf': 34,
#  'summer': 34,
#  'showtime': 34,
#  'spicy': 34,
#  'doctor': 34,
#  'kevin': 34,
#  'gun': 34,
#  'return': 34,
#  'missed': 34,
#  'level': 33,
#  'hd': 33,
#  'myke': 33,
#  'olivia': 33,
#  'welcome': 33,
#  'performs': 33,
#  'two': 33,
#  'presents': 33,
#  'police': 33,
#  'tonight': 33,
#  'character': 33,
#  'buy': 33,
#  'says': 33,
#  'loki': 33,
#  'perfect': 33,
#  'wandavision': 33,
#  'pooh': 33,
#  'million': 33,
#  'being': 33,
#  'pt': 33,
#  'using': 33,
#  'mario': 33,
#  'paris': 33,
#  'moments': 33,
#  'duty': 33,
#  'ford': 33,
#  'shopping': 33,
#  'map': 32,
#  'debut': 32,
#  'anthony': 32,
#  'cover': 32,
#  'testing': 32,
#  'block': 32,
#  'american': 32,
#  "you're": 32,
#  'shooting': 32,
#  'imposter': 32,
#  'date': 32,
#  'football': 32,
#  'dustin': 32,
#  'grupo': 32,
#  'genshin': 32,
#  'sean': 32,
#  'surprise': 32,
#  'championship': 32,
#  'rich': 32,
#  'great': 32,
#  'finals': 32,
#  'tnt': 32,
#  'honest': 32,
#  'morning': 31,
#  'galaxy': 31,
#  'jimmy': 31,
#  'still': 31,
#  'recap': 31,
#  'ksi': 31,
#  '25': 31,
#  'shiesty': 31,
#  'its': 31,
#  'change': 31,
#  'girlfriend': 31,
#  'aew': 31,
#  'capitol': 31,
#  'reacting': 31,
#  'role': 31,
#  'very': 31,
#  'selena': 30,
#  'videos': 30,
#  'jack': 30,
#  'golden': 30,
#  'god': 30,
#  'charli': 30,
#  'goodbye': 30,
#  'mom': 30,
#  'woman': 30,
#  'tiny': 30,
#  'america': 30,
#  'magic': 30,
#  'ryan': 30,
#  'bbc': 30,
#  'jr': 30,
#  'beauty': 30,
#  'meghan': 30,
#  '2022': 30,
#  'june': 30,
#  'huge': 30,
#  'december': 30,
#  'weird': 30,
#  'lee': 30,
#  'resumen': 30,
#  'spent': 29,
#  'prank': 29,
#  'cyrus': 29,
#  'jam': 29,
#  'playing': 29,
#  'noah': 29,
#  'concert': 29,
#  'escape': 29,
#  'dragon': 29,
#  'winter': 29,
#  'playstation': 29,
#  'mini': 29,
#  'juventus': 29,
#  "i've": 29,
#  'evil': 29,
#  'true': 29,
#  'channel': 29,
#  'breaks': 29,
#  'crew': 29,
#  'key': 29,
#  'should': 29,
#  "didn't": 29,
#  'smash': 29,
#  'ddg': 29,
#  'biggest': 29,
#  'satisfying': 28,
#  'impossible': 28,
#  'spider': 28,
#  'election': 28,
#  'drake': 28,
#  'rodrigo': 28,
#  'gone': 28,
#  'brawl': 28,
#  'guess': 28,
#  "what's": 28,
#  'record': 28,
#  'mtv': 28,
#  'road': 28,
#  '23': 28,
#  'across': 28,
#  'sings': 28,
#  'boss': 28,
#  'covid': 28,
#  'questions': 28,
#  'luke': 28,
#  'where': 28,
#  'kill': 28,
#  'internet': 28,
#  'anime': 28,
#  'secrets': 28,
#  'dark': 28,
#  'poirier': 28,
#  'chelsea': 28,
#  'run': 28,
#  'smackdown': 28,
#  'playoffs': 28,
#  'crafts': 28,
#  'pregnancy': 28,
#  'gomez': 27,
#  'save': 27,
#  'miley': 27,
#  'box': 27,
#  'epic': 27,
#  'gave': 27,
#  'island': 27,
#  'said': 27,
#  'dababy': 27,
#  'holiday': 27,
#  'messi': 27,
#  'dc': 27,
#  'travis': 27,
#  'son': 27,
#  'comeback': 27,
#  '1000': 27,
#  'hall': 27,
#  'lose': 27,
#  'morty': 27,
#  'together': 27,
#  'pov': 27,
#  'tok': 27,
#  'rock': 27,
#  're': 27,
#  'guy': 27,
#  'hair': 27,
#  'breaking': 27,
#  '1v1': 27,
#  'shannon': 27,
#  'body': 26,
#  'leave': 26,
#  'largest': 26,
#  'mars': 26,
#  'sonic': 26,
#  'visualizer': 26,
#  'green': 26,
#  'santa': 26,
#  'mayweather': 26,
#  'other': 26,
#  'wayne': 26,
#  'speed': 26,
#  'showcase': 26,
#  'think': 26,
#  'vogue': 26,
#  'serie': 26,
#  'zhc': 26,
#  'seen': 26,
#  'fury': 26,
#  'babish': 26,
#  'title': 26,
#  'under': 26,
#  'gaming': 26,
#  'something': 26,
#  'davis': 26,
#  'goals': 26,
#  'could': 26,
#  'extra': 26,
#  'youtubers': 26,
#  'michael': 26,
#  'daylight': 26,
#  'details': 26,
#  'skip': 26,
#  'cream': 25,
#  'trick': 25,
#  'amazon': 25,
#  'october': 25,
#  'lo': 25,
#  'swift': 25,
#  'want': 25,
#  'farruko': 25,
#  'alejandro': 25,
#  'players': 25,
#  'won': 25,
#  'used': 25,
#  'floyd': 25,
#  'electric': 25,
#  'each': 25,
#  'morgan': 25,
#  'bang': 25,
#  'premiere': 25,
#  'entire': 25,
#  'smoke': 25,
#  'these': 25,
#  'von': 25,
#  'rocket': 25,
#  'madrid': 25,
#  'psg': 25,
#  'cake': 25,
#  'cut': 25,
#  'george': 25,
#  'played': 25,
#  'tell': 25,
#  'champion': 25,
#  'blind': 25,
#  'raw': 25,
#  'truck': 25,
#  'woodley': 25,
#  'delivery': 25,
#  'some': 25,
#  'suns': 25,
#  'talks': 25,
#  'eddie': 25,
#  'balvin': 24,
#  'dad': 24,
#  'billboard': 24,
#  'prison': 24,
#  'forever': 24,
#  'england': 24,
#  'bowl': 24,
#  'start': 24,
#  "america's": 24,
#  'debate': 24,
#  'ver': 24,
#  'david': 24,
#  'laroi': 24,
#  'logan': 24,
#  'dancing': 24,
#  'cartoon': 24,
#  'massive': 24,
#  'impressions': 24,
#  '27': 24,
#  'lie': 24,
#  'buccaneers': 24,
#  'prix': 24,
#  'took': 24,
#  'store': 24,
#  'telling': 24,
#  'moneybagg': 24,
#  'tesla': 24,
#  'tips': 24,
#  'wedding': 24,
#  '42': 24,
#  'rap': 24,
#  'national': 24,
#  'adesanya': 24,
#  'complex': 24,
#  'scp': 24,
#  'butter': 23,
#  'itzy': 23,
#  'harlow': 23,
#  'practice': 23,
#  'minute': 23,
#  'pay': 23,
#  'town': 23,
#  'phone': 23,
#  'attack': 23,
#  'kim': 23,
#  'person': 23,
#  'them': 23,
#  'earth': 23,
#  'tjay': 23,
#  'royal': 23,
#  'ross': 23,
#  'jones': 23,
#  'kitchen': 23,
#  'bros': 23,
#  'amazing': 23,
#  'tim': 23,
#  'winner': 23,
#  'chicken': 23,
#  'gucci': 23,
#  'club': 23,
#  'revealed': 23,
#  'reveals': 23,
#  'golf': 23,
#  'mukbang': 23,
#  'late': 23,
#  'nikkietutorials': 23,
#  'hits': 23,
#  'boys': 23,
#  'binging': 23,
#  'firme': 23,
#  'dugg': 23,
#  'pbc': 23,
#  'having': 23,
#  'conan': 23,
#  'squad': 23,
#  'taste': 23,
#  'find': 23,
#  'warriors': 23,
#  'rare': 23,
#  'following': 23,
#  'hard': 23,
#  'arsenal': 23,
#  'tyron': 23,
#  'nuggets': 23,
#  'finding': 23,
#  'calls': 23,
#  'going': 23,
#  'asmr': 23,
#  'destiny': 23,
#  'sec': 23,
#  'talent': 22,
#  'ozuna': 22,
#  'door': 22,
#  'would': 22,
#  'samsung': 22,
#  'eat': 22,
#  'cars': 22,
#  'arrested': 22,
#  'brother': 22,
#  'blake': 22,
#  'rockets': 22,
#  'clans': 22,
#  'finale': 22,
#  'blood': 22,
#  'prime': 22,
#  'thug': 22,
#  'enhypen': 22,
#  'kylie': 22,
#  'blue': 22,
#  '1st': 22,
#  'tribute': 22,
#  'fall': 22,
#  'drive': 22,
#  'fastest': 22,
#  'online': 22,
#  'items': 22,
#  'mr': 22,
#  'liverpool': 22,
#  'losing': 22,
#  'gala': 22,
#  'trippie': 22,
#  'redd': 22,
#  'drag': 22,
#  'nick': 22,
#  'cinematic': 22,
#  'craft': 22,
#  'miami': 22,
#  'puppy': 22,
#  'gq': 22,
#  'twin': 22,
#  'toosii': 22,
#  'february': 22,
#  'cook': 22,
#  'bunny': 21,
#  'universe': 21,
#  'garcia': 21,
#  'head': 21,
#  'ateez': 21,
#  'rematch': 21,
#  'doing': 21,
#  'alfa': 21,
#  'random': 21,
#  'fast': 21,
#  'believe': 21,
#  'addison': 21,
#  'card': 21,
#  'characters': 21,
#  'ronaldo': 21,
#  'en': 21,
#  'tried': 21,
#  'chiefs': 21,
#  'crash': 21,
#  'paramount': 21,
#  'mandalorian': 21,
#  'come': 21,
#  'thoughts': 21,
#  'cast': 21,
#  'doll': 21,
#  'around': 21,
#  'takes': 21,
#  'roman': 21,
#  'reigns': 21,
#  'iii': 21,
#  '60': 21,
#  'ultra': 21,
#  'worth': 21,
#  'facts': 21,
#  'freshman': 21,
#  'base': 21,
#  'kardashian': 21,
#  'bayern': 21,
#  'euro': 21,
#  'office': 21,
#  'killed': 21,
#  'sneaker': 21,
#  'nct': 20,
#  'dj': 20,
#  'starring': 20,
#  '500': 20,
#  'cool': 20,
#  'diamond': 20,
#  'rauw': 20,
#  'harris': 20,
#  'txt': 20,
#  'charles': 20,
#  'victory': 20,
#  'track': 20,
#  'canelo': 20,
#  'mask': 20,
#  '200': 20,
#  'experience': 20,
#  'happy': 20,
#  'fan': 20,
#  'everyone': 20,
#  'missing': 20,
#  'scores': 20,
#  'burger': 20,
#  'set': 20,
#  'street': 20,
#  'whole': 20,
#  'fans': 20,
#  'country': 20,
#  'buying': 20,
#  'injury': 20,
#  'plays': 20,
#  'many': 20,
#  'own': 20,
#  'oliver': 20,
#  'much': 20,
#  'today': 20,
#  'shocking': 20,
#  'any': 20,
#  'system': 20,
#  'ocean': 20,
#  'station': 20,
#  'stories': 20,
#  'wants': 20,
#  'ops': 20,
#  'smarter': 20,
#  'cowboys': 20,
#  'camera': 20,
#  'sister': 20,
#  ...}

# %%
from sklearn.feature_extraction import _stop_words
stop_words = tuple(_stop_words.ENGLISH_STOP_WORDS)
#stop_words[:10]

# %%
one_word_filtered = {k: v for k, v in one_word.items() if k not in stop_words}
one_word_filtered
# Out:
# {'official': 1998,
#  'video': 1759,
#  'vs': 867,
#  'highlights': 734,
#  'music': 638,
#  '2021': 634,
#  'trailer': 624,
#  '2020': 585,
#  'minecraft': 551,
#  'new': 538,
#  'game': 480,
#  'ft': 434,
#  'shorts': 399,
#  'season': 308,
#  'lil': 300,
#  'live': 290,
#  'feat': 271,
#  'day': 253,
#  '000': 229,
#  'nba': 229,
#  'audio': 223,
#  'episode': 218,
#  'world': 205,
#  'life': 202,
#  'fortnite': 199,
#  '10': 196,
#  'oficial': 194,
#  'baby': 193,
#  'challenge': 180,
#  'best': 179,
#  'bts': 178,
#  'sports': 176,
#  'teaser': 171,
#  'night': 168,
#  'nfl': 166,
#  'week': 166,
#  'house': 163,
#  'update': 153,
#  '100': 152,
#  'reveal': 152,
#  'time': 149,
#  'reacts': 149,
#  'home': 143,
#  'dream': 140,
#  'real': 133,
#  'got': 131,
#  '12': 127,
#  'ufc': 126,
#  'iphone': 125,
#  'final': 125,
#  'big': 124,
#  'review': 124,
#  'league': 121,
#  "i'm": 121,
#  'ep': 117,
#  'series': 115,
#  'win': 115,
#  'el': 114,
#  'friday': 114,
#  'man': 113,
#  'like': 113,
#  'news': 113,
#  'fight': 112,
#  'remix': 111,
#  '21': 111,
#  'mv': 109,
#  'la': 109,
#  'days': 109,
#  'love': 108,
#  'reaction': 107,
#  'things': 106,
#  'black': 104,
#  'tour': 101,
#  'car': 100,
#  'paul': 99,
#  'theory': 97,
#  'lakers': 97,
#  'make': 96,
#  'people': 96,
#  'battle': 96,
#  'lyric': 95,
#  'mod': 94,
#  'animation': 93,
#  'funkin': 92,
#  'test': 91,
#  '13': 90,
#  'family': 90,
#  'bad': 89,
#  'open': 89,
#  'watch': 89,
#  'pro': 89,
#  'super': 88,
#  'extended': 88,
#  '20': 87,
#  'breakdown': 87,
#  'awards': 85,
#  'food': 85,
#  'song': 84,
#  'friends': 84,
#  'legends': 84,
#  'event': 83,
#  'wins': 83,
#  'happened': 83,
#  'try': 83,
#  'performance': 82,
#  'nbc': 82,
#  'inside': 82,
#  'gets': 82,
#  'movie': 82,
#  'star': 82,
#  'war': 79,
#  'city': 79,
#  "don't": 78,
#  "it's": 78,
#  'cbs': 78,
#  'scenes': 77,
#  'look': 77,
#  'story': 77,
#  'year': 76,
#  'apple': 75,
#  'bought': 75,
#  'play': 74,
#  'dead': 74,
#  '24': 73,
#  '14': 73,
#  'goes': 71,
#  '30': 71,
#  'king': 71,
#  'hot': 70,
#  'james': 70,
#  'disney': 70,
#  '15': 70,
#  'gameplay': 70,
#  "can't": 69,
#  'hours': 69,
#  'react': 69,
#  'stephen': 69,
#  'broke': 68,
#  'justin': 68,
#  'exclusive': 68,
#  'trump': 68,
#  'young': 67,
#  'did': 67,
#  'pregnant': 67,
#  'free': 66,
#  'know': 66,
#  'making': 66,
#  '17': 66,
#  'announcement': 66,
#  'dance': 65,
#  'durk': 65,
#  'max': 65,
#  'explained': 65,
#  'old': 64,
#  'secret': 64,
#  'tiktok': 63,
#  'cold': 63,
#  'interview': 63,
#  'face': 63,
#  '11': 63,
#  '방탄소년단': 62,
#  'insane': 62,
#  'easter': 62,
#  'death': 62,
#  'really': 62,
#  'round': 62,
#  'talk': 61,
#  'hardcore': 61,
#  'ps5': 61,
#  'birthday': 60,
#  'good': 60,
#  "world's": 60,
#  'school': 60,
#  'special': 60,
#  'marvel': 60,
#  'just': 60,
#  'build': 59,
#  'cat': 59,
#  'hermitcraft': 59,
#  'way': 58,
#  'joe': 58,
#  'games': 58,
#  'ball': 58,
#  'united': 58,
#  'boy': 58,
#  'espn': 58,
#  'los': 57,
#  'unboxing': 57,
#  'fc': 57,
#  'money': 56,
#  'bieber': 56,
#  'beat': 56,
#  'friend': 56,
#  'survived': 56,
#  'makeup': 56,
#  'jake': 56,
#  'nas': 55,
#  'film': 55,
#  'dog': 55,
#  'trying': 55,
#  'cup': 55,
#  'finally': 54,
#  'guys': 54,
#  'ucl': 54,
#  'crazy': 52,
#  'youtube': 52,
#  'snl': 52,
#  'ultimate': 52,
#  'royale': 52,
#  'race': 52,
#  'barcelona': 52,
#  'polo': 51,
#  'wild': 51,
#  'building': 51,
#  'actually': 51,
#  'john': 51,
#  'dynamite': 50,
#  'kids': 50,
#  'harry': 50,
#  'high': 50,
#  'christmas': 50,
#  'kid': 50,
#  'apex': 50,
#  'getting': 50,
#  'ice': 49,
#  'mystery': 49,
#  'stars': 49,
#  'prince': 49,
#  'years': 49,
#  'september': 49,
#  'tv': 49,
#  'custom': 49,
#  'smp': 49,
#  'wrong': 49,
#  'manchester': 49,
#  'tokyo': 49,
#  'end': 48,
#  'need': 48,
#  'netflix': 48,
#  'edition': 48,
#  'say': 48,
#  'cooking': 48,
#  'ending': 47,
#  "d'amelio": 47,
#  'freestyle': 47,
#  'hacks': 47,
#  'chris': 47,
#  'minutes': 47,
#  'usa': 47,
#  '50': 46,
#  'shot': 46,
#  'president': 46,
#  'clash': 46,
#  'gold': 46,
#  'truth': 46,
#  'room': 46,
#  'worst': 46,
#  'tik': 46,
#  'post': 46,
#  'ariana': 45,
#  'biden': 45,
#  'better': 45,
#  'press': 45,
#  'halloween': 45,
#  'dixie': 45,
#  'meet': 45,
#  'skin': 45,
#  'history': 45,
#  'nets': 45,
#  'taylor': 44,
#  'makes': 44,
#  'emotional': 44,
#  'team': 44,
#  'twins': 44,
#  'guide': 44,
#  'moving': 44,
#  'eating': 43,
#  'billie': 43,
#  'power': 43,
#  'laugh': 43,
#  'tom': 43,
#  'does': 43,
#  'grand': 43,
#  'gta': 43,
#  'hit': 43,
#  'pokémon': 43,
#  '19': 43,
#  'clippers': 43,
#  'vlog': 43,
#  'eggs': 43,
#  'turn': 42,
#  'eilish': 42,
#  'grande': 42,
#  'fox': 42,
#  'introducing': 42,
#  '4k': 42,
#  '16': 42,
#  'album': 42,
#  'boyfriend': 42,
#  'work': 42,
#  'voice': 42,
#  'chapter': 42,
#  'mission': 42,
#  'kelly': 42,
#  "here's": 42,
#  'da': 41,
#  'lost': 41,
#  'party': 41,
#  'break': 41,
#  'squid': 41,
#  '18': 41,
#  'away': 41,
#  'rick': 41,
#  'white': 41,
#  'animated': 41,
#  'flight': 41,
#  'art': 41,
#  'nintendo': 41,
#  'roblox': 41,
#  'olympics': 41,
#  'savage': 40,
#  'future': 40,
#  'red': 40,
#  'queen': 40,
#  'don': 40,
#  'launch': 40,
#  'scott': 40,
#  'met': 40,
#  'wars': 40,
#  'cole': 40,
#  'heat': 40,
#  'blackpink': 39,
#  'monster': 39,
#  'coming': 39,
#  'space': 39,
#  'different': 39,
#  '22': 39,
#  'ready': 39,
#  'surprising': 39,
#  'youngboy': 39,
#  'little': 39,
#  'slow': 39,
#  'faze': 39,
#  'premier': 39,
#  'gender': 39,
#  'warzone': 39,
#  'megan': 38,
#  'egg': 38,
#  'stop': 38,
#  'del': 38,
#  "we're": 38,
#  'stage': 38,
#  'xbox': 38,
#  'conor': 38,
#  'impact': 38,
#  'machine': 38,
#  'state': 38,
#  'lebron': 38,
#  'match': 38,
#  'built': 38,
#  'girl': 37,
#  'fake': 37,
#  'right': 37,
#  'yo': 37,
#  'original': 37,
#  'studios': 37,
#  'version': 37,
#  'wwe': 37,
#  'switch': 37,
#  'mcgregor': 37,
#  'wings': 37,
#  'ios': 37,
#  'van': 37,
#  'loss': 37,
#  '2k22': 37,
#  'thee': 36,
#  'stallion': 36,
#  'park': 36,
#  'giant': 36,
#  'hbo': 36,
#  'player': 36,
#  'light': 36,
#  'basketball': 36,
#  'opening': 36,
#  'pass': 36,
#  'champions': 36,
#  'conference': 36,
#  'viral': 36,
#  'collection': 36,
#  'undisputed': 36,
#  'girls': 35,
#  'twice': 35,
#  'stray': 35,
#  'weeknd': 35,
#  'towers': 35,
#  'doja': 35,
#  'shop': 35,
#  'let': 35,
#  'legend': 35,
#  'mike': 35,
#  'water': 35,
#  'west': 35,
#  'tyson': 35,
#  'brown': 35,
#  'israel': 35,
#  'ones': 35,
#  'august': 35,
#  'hurricane': 35,
#  'bucks': 35,
#  'funny': 34,
#  'pop': 34,
#  'went': 34,
#  'jay': 34,
#  'item': 34,
#  'air': 34,
#  'sidemen': 34,
#  'fnf': 34,
#  'summer': 34,
#  'showtime': 34,
#  'spicy': 34,
#  'doctor': 34,
#  'kevin': 34,
#  'gun': 34,
#  'return': 34,
#  'missed': 34,
#  'level': 33,
#  'hd': 33,
#  'myke': 33,
#  'olivia': 33,
#  'welcome': 33,
#  'performs': 33,
#  'presents': 33,
#  'police': 33,
#  'tonight': 33,
#  'character': 33,
#  'buy': 33,
#  'says': 33,
#  'loki': 33,
#  'perfect': 33,
#  'wandavision': 33,
#  'pooh': 33,
#  'million': 33,
#  'pt': 33,
#  'using': 33,
#  'mario': 33,
#  'paris': 33,
#  'moments': 33,
#  'duty': 33,
#  'ford': 33,
#  'shopping': 33,
#  'map': 32,
#  'debut': 32,
#  'anthony': 32,
#  'cover': 32,
#  'testing': 32,
#  'block': 32,
#  'american': 32,
#  "you're": 32,
#  'shooting': 32,
#  'imposter': 32,
#  'date': 32,
#  'football': 32,
#  'dustin': 32,
#  'grupo': 32,
#  'genshin': 32,
#  'sean': 32,
#  'surprise': 32,
#  'championship': 32,
#  'rich': 32,
#  'great': 32,
#  'finals': 32,
#  'tnt': 32,
#  'honest': 32,
#  'morning': 31,
#  'galaxy': 31,
#  'jimmy': 31,
#  'recap': 31,
#  'ksi': 31,
#  '25': 31,
#  'shiesty': 31,
#  'change': 31,
#  'girlfriend': 31,
#  'aew': 31,
#  'capitol': 31,
#  'reacting': 31,
#  'role': 31,
#  'selena': 30,
#  'videos': 30,
#  'jack': 30,
#  'golden': 30,
#  'god': 30,
#  'charli': 30,
#  'goodbye': 30,
#  'mom': 30,
#  'woman': 30,
#  'tiny': 30,
#  'america': 30,
#  'magic': 30,
#  'ryan': 30,
#  'bbc': 30,
#  'jr': 30,
#  'beauty': 30,
#  'meghan': 30,
#  '2022': 30,
#  'june': 30,
#  'huge': 30,
#  'december': 30,
#  'weird': 30,
#  'lee': 30,
#  'resumen': 30,
#  'spent': 29,
#  'prank': 29,
#  'cyrus': 29,
#  'jam': 29,
#  'playing': 29,
#  'noah': 29,
#  'concert': 29,
#  'escape': 29,
#  'dragon': 29,
#  'winter': 29,
#  'playstation': 29,
#  'mini': 29,
#  'juventus': 29,
#  "i've": 29,
#  'evil': 29,
#  'true': 29,
#  'channel': 29,
#  'breaks': 29,
#  'crew': 29,
#  'key': 29,
#  "didn't": 29,
#  'smash': 29,
#  'ddg': 29,
#  'biggest': 29,
#  'satisfying': 28,
#  'impossible': 28,
#  'spider': 28,
#  'election': 28,
#  'drake': 28,
#  'rodrigo': 28,
#  'gone': 28,
#  'brawl': 28,
#  'guess': 28,
#  "what's": 28,
#  'record': 28,
#  'mtv': 28,
#  'road': 28,
#  '23': 28,
#  'sings': 28,
#  'boss': 28,
#  'covid': 28,
#  'questions': 28,
#  'luke': 28,
#  'kill': 28,
#  'internet': 28,
#  'anime': 28,
#  'secrets': 28,
#  'dark': 28,
#  'poirier': 28,
#  'chelsea': 28,
#  'run': 28,
#  'smackdown': 28,
#  'playoffs': 28,
#  'crafts': 28,
#  'pregnancy': 28,
#  'gomez': 27,
#  'save': 27,
#  'miley': 27,
#  'box': 27,
#  'epic': 27,
#  'gave': 27,
#  'island': 27,
#  'said': 27,
#  'dababy': 27,
#  'holiday': 27,
#  'messi': 27,
#  'dc': 27,
#  'travis': 27,
#  'son': 27,
#  'comeback': 27,
#  '1000': 27,
#  'hall': 27,
#  'lose': 27,
#  'morty': 27,
#  'pov': 27,
#  'tok': 27,
#  'rock': 27,
#  'guy': 27,
#  'hair': 27,
#  'breaking': 27,
#  '1v1': 27,
#  'shannon': 27,
#  'body': 26,
#  'leave': 26,
#  'largest': 26,
#  'mars': 26,
#  'sonic': 26,
#  'visualizer': 26,
#  'green': 26,
#  'santa': 26,
#  'mayweather': 26,
#  'wayne': 26,
#  'speed': 26,
#  'showcase': 26,
#  'think': 26,
#  'vogue': 26,
#  'serie': 26,
#  'zhc': 26,
#  'seen': 26,
#  'fury': 26,
#  'babish': 26,
#  'title': 26,
#  'gaming': 26,
#  'davis': 26,
#  'goals': 26,
#  'extra': 26,
#  'youtubers': 26,
#  'michael': 26,
#  'daylight': 26,
#  'details': 26,
#  'skip': 26,
#  'cream': 25,
#  'trick': 25,
#  'amazon': 25,
#  'october': 25,
#  'lo': 25,
#  'swift': 25,
#  'want': 25,
#  'farruko': 25,
#  'alejandro': 25,
#  'players': 25,
#  'won': 25,
#  'used': 25,
#  'floyd': 25,
#  'electric': 25,
#  'morgan': 25,
#  'bang': 25,
#  'premiere': 25,
#  'entire': 25,
#  'smoke': 25,
#  'von': 25,
#  'rocket': 25,
#  'madrid': 25,
#  'psg': 25,
#  'cake': 25,
#  'cut': 25,
#  'george': 25,
#  'played': 25,
#  'tell': 25,
#  'champion': 25,
#  'blind': 25,
#  'raw': 25,
#  'truck': 25,
#  'woodley': 25,
#  'delivery': 25,
#  'suns': 25,
#  'talks': 25,
#  'eddie': 25,
#  'balvin': 24,
#  'dad': 24,
#  'billboard': 24,
#  'prison': 24,
#  'forever': 24,
#  'england': 24,
#  'bowl': 24,
#  'start': 24,
#  "america's": 24,
#  'debate': 24,
#  'ver': 24,
#  'david': 24,
#  'laroi': 24,
#  'logan': 24,
#  'dancing': 24,
#  'cartoon': 24,
#  'massive': 24,
#  'impressions': 24,
#  '27': 24,
#  'lie': 24,
#  'buccaneers': 24,
#  'prix': 24,
#  'took': 24,
#  'store': 24,
#  'telling': 24,
#  'moneybagg': 24,
#  'tesla': 24,
#  'tips': 24,
#  'wedding': 24,
#  '42': 24,
#  'rap': 24,
#  'national': 24,
#  'adesanya': 24,
#  'complex': 24,
#  'scp': 24,
#  'butter': 23,
#  'itzy': 23,
#  'harlow': 23,
#  'practice': 23,
#  'minute': 23,
#  'pay': 23,
#  'town': 23,
#  'phone': 23,
#  'attack': 23,
#  'kim': 23,
#  'person': 23,
#  'earth': 23,
#  'tjay': 23,
#  'royal': 23,
#  'ross': 23,
#  'jones': 23,
#  'kitchen': 23,
#  'bros': 23,
#  'amazing': 23,
#  'tim': 23,
#  'winner': 23,
#  'chicken': 23,
#  'gucci': 23,
#  'club': 23,
#  'revealed': 23,
#  'reveals': 23,
#  'golf': 23,
#  'mukbang': 23,
#  'late': 23,
#  'nikkietutorials': 23,
#  'hits': 23,
#  'boys': 23,
#  'binging': 23,
#  'firme': 23,
#  'dugg': 23,
#  'pbc': 23,
#  'having': 23,
#  'conan': 23,
#  'squad': 23,
#  'taste': 23,
#  'warriors': 23,
#  'rare': 23,
#  'following': 23,
#  'hard': 23,
#  'arsenal': 23,
#  'tyron': 23,
#  'nuggets': 23,
#  'finding': 23,
#  'calls': 23,
#  'going': 23,
#  'asmr': 23,
#  'destiny': 23,
#  'sec': 23,
#  'talent': 22,
#  'ozuna': 22,
#  'door': 22,
#  'samsung': 22,
#  'eat': 22,
#  'cars': 22,
#  'arrested': 22,
#  'brother': 22,
#  'blake': 22,
#  'rockets': 22,
#  'clans': 22,
#  'finale': 22,
#  'blood': 22,
#  'prime': 22,
#  'thug': 22,
#  'enhypen': 22,
#  'kylie': 22,
#  'blue': 22,
#  '1st': 22,
#  'tribute': 22,
#  'fall': 22,
#  'drive': 22,
#  'fastest': 22,
#  'online': 22,
#  'items': 22,
#  'mr': 22,
#  'liverpool': 22,
#  'losing': 22,
#  'gala': 22,
#  'trippie': 22,
#  'redd': 22,
#  'drag': 22,
#  'nick': 22,
#  'cinematic': 22,
#  'craft': 22,
#  'miami': 22,
#  'puppy': 22,
#  'gq': 22,
#  'twin': 22,
#  'toosii': 22,
#  'february': 22,
#  'cook': 22,
#  'bunny': 21,
#  'universe': 21,
#  'garcia': 21,
#  'head': 21,
#  'ateez': 21,
#  'rematch': 21,
#  'doing': 21,
#  'alfa': 21,
#  'random': 21,
#  'fast': 21,
#  'believe': 21,
#  'addison': 21,
#  'card': 21,
#  'characters': 21,
#  'ronaldo': 21,
#  'en': 21,
#  'tried': 21,
#  'chiefs': 21,
#  'crash': 21,
#  'paramount': 21,
#  'mandalorian': 21,
#  'come': 21,
#  'thoughts': 21,
#  'cast': 21,
#  'doll': 21,
#  'takes': 21,
#  'roman': 21,
#  'reigns': 21,
#  'iii': 21,
#  '60': 21,
#  'ultra': 21,
#  'worth': 21,
#  'facts': 21,
#  'freshman': 21,
#  'base': 21,
#  'kardashian': 21,
#  'bayern': 21,
#  'euro': 21,
#  'office': 21,
#  'killed': 21,
#  'sneaker': 21,
#  'nct': 20,
#  'dj': 20,
#  'starring': 20,
#  '500': 20,
#  'cool': 20,
#  'diamond': 20,
#  'rauw': 20,
#  'harris': 20,
#  'txt': 20,
#  'charles': 20,
#  'victory': 20,
#  'track': 20,
#  'canelo': 20,
#  'mask': 20,
#  '200': 20,
#  'experience': 20,
#  'happy': 20,
#  'fan': 20,
#  'missing': 20,
#  'scores': 20,
#  'burger': 20,
#  'set': 20,
#  'street': 20,
#  'fans': 20,
#  'country': 20,
#  'buying': 20,
#  'injury': 20,
#  'plays': 20,
#  'oliver': 20,
#  'today': 20,
#  'shocking': 20,
#  'ocean': 20,
#  'station': 20,
#  'stories': 20,
#  'wants': 20,
#  'ops': 20,
#  'smarter': 20,
#  'cowboys': 20,
#  'camera': 20,
#  'sister': 20,
#  'texas': 20,
#  'trail': 20,
#  'halen': 20,
#  'comments': 20,
#  'trailers': 20,
#  'goles': 20,
#  'tudn': 20,
#  'fish': 19,
#  'tournament': 19,
#  'khabib': 19,
#  'hide': 19,
#  'jackson': 19,
#  'wheeler': 19,
#  'lopez': 19,
#  'shows': 19,
#  'rod': 19,
#  'logic': 19,
#  'die': 19,
#  'kills': 19,
#  "minecraft's": 19,
#  'herbo': 19,
#  'sea': 19,
#  'happens': 19,
#  'released': 19,
#  'outfits': 19,
#  'july': 19,
#  'starship': 19,
#  'short': 19,
#  'meets': 19,
#  'copa': 19,
#  'saint': 19,
#  'drop': 19,
#  'winning': 19,
#  'college': 19,
#  'wilder': 19,
#  'op': 19,
#  'mods': 19,
#  'zero': 19,
#  'tree': 19,
#  'intro': 19,
#  'mo': 19,
#  'xxl': 19,
#  'returns': 19,
#  'left': 19,
#  'florida': 19,
#  'blazers': 19,
#  '2hype': 19,
#  'merrell': 19,
#  'kuwtk': 19,
#  'cardi': 18,
#  'dress': 18,
#  'rapper': 18,
#  'wish': 18,
#  'job': 18,
#  'january': 18,
#  'color': 18,
#  '에이티즈': 18,
#  'paint': 18,
#  'daddy': 18,
#  '40': 18,
#  'hotel': 18,
#  'makeover': 18,
#  'motion': 18,
#  'hq': 18,
#  'cyberpunk': 18,
#  '2077': 18,
#  'snoop': 18,
#  'jenner': 18,
#  'calling': 18,
#  'desk': 18,
#  'demi': 18,
#  'eyes': 18,
#  'smith': 18,
#  'beck': 18,
#  'adult': 18,
#  'mma': 18,
#  'te': 18,
#  'rey': 18,
#  'rochy': 18,
#  'gives': 18,
#  'birth': 18,
#  'fredo': 18,
#  'double': 18,
#  'pain': 18,
#  '29': 18,
#  'toks': 18,
#  'challenges': 18,
#  'model': 18,
#  'speech': 18,
#  'germain': 18,
#  'macdonald': 18,
#  'bailey': 18,
#  'speaks': 18,
#  'og': 18,
#  'release': 18,
#  'naruto': 18,
#  'johnson': 18,
#  'help': 18,
#  'use': 18,
#  'message': 18,
#  'pizza': 18,
#  'williams': 18,
#  'early': 18,
#  'clan': 18,
#  'court': 18,
#  'journey': 18,
#  'explains': 18,
#  'mavericks': 18,
#  'bein': 18,
#  'trip': 18,
#  'apartment': 18,
#  'rainbow': 18,
#  'starlink': 18,
#  'ko': 18,
#  'méxico': 18,
#  'ground': 17,
#  'oddly': 17,
#  'mx': 17,
#  'tears': 17,
#  'results': 17,
#  'mobile': 17,
#  'india': 17,
#  'extreme': 17,
#  'lv': 17,
#  'nail': 17,
#  'mode': 17,
#  'stuff': 17,
#  'legacy': 17,
#  'ii': 17,
#  'iq': 17,
#  'manhunt': 17,
#  ...}

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# takes dictionary and displays bar graph of words and frequency
# parameters: 
#  -data: dict to graph, 
#  -x_amt: number of items, 
#  -title: title of graph in quotes ('My Title')
#  -image_fn: optional filename to save image in quotes ('image.png')
def plot_word_freq(data, x_amt, title, image_fn='image.png'):
    first_x = dict(itertools.islice(data.items(), int(x_amt)))
    words = list(first_x.keys())
    freq = list(first_x.values())
    
    plt.figure(figsize=(12,8))
    sns.barplot(x=freq, y=words)
    plt.title(title, fontsize=20)
    plt.xlabel('Frequency', fontsize=16)
    plt.ylabel('Words/Phrases', fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    
    for i, v in enumerate(freq):
        plt.text(v, i, int(v), fontsize=12, alpha=0.75, va='center')
    script_dir = os.path.dirname('')
    image_dir = os.path.join(script_dir, 'images/')
    plt.savefig(image_dir + image_fn)
    plt.show()

# %%
plot_word_freq(one_word_filtered, 25, 'Most Common Words', 'common_words.png')

# %%
# most common 2-word phrases in titles
two_words = print_dict_sort(title_analysis(final['title'], 2), True)
two_words
# Out:
# {'official video': 718,
#  'music video': 569,
#  'official music': 526,
#  'among us': 243,
#  'official trailer': 224,
#  'video oficial': 188,
#  'official audio': 172,
#  'game highlights': 172,
#  'in the': 170,
#  'of the': 160,
#  'full game': 147,
#  'to the': 139,
#  'reacts to': 137,
#  'minecraft but': 131,
#  'how to': 126,
#  'highlights nfl': 113,
#  'on the': 109,
#  'friday night': 104,
#  'at the': 98,
#  'nfl 2020': 94,
#  'for the': 91,
#  'lyric video': 91,
#  'night funkin': 91,
#  'from the': 90,
#  'in minecraft': 82,
#  'in among': 78,
#  'the world': 73,
#  'cbs sports': 71,
#  'extended highlights': 71,
#  'video ft': 70,
#  'with the': 70,
#  'nbc sports': 67,
#  'lil durk': 65,
#  'week highlights': 65,
#  'lil baby': 61,
#  'react to': 61,
#  'official teaser': 60,
#  'the first': 60,
#  'iphone 12': 59,
#  'bts 방탄소년단': 58,
#  'behind the': 57,
#  'official lyric': 57,
#  'the best': 57,
#  'and the': 55,
#  'first take': 55,
#  'jake paul': 52,
#  'the scenes': 51,
#  'this is': 51,
#  'the most': 51,
#  'what happened': 51,
#  'is the': 51,
#  'the new': 51,
#  'highlights ucl': 50,
#  'justin bieber': 48,
#  'out of': 46,
#  'apex legends': 46,
#  '24 hours': 45,
#  'live from': 44,
#  'first time': 44,
#  'ucl on': 43,
#  'on cbs': 43,
#  'lil nas': 42,
#  'billie eilish': 42,
#  'ariana grande': 42,
#  'reveal trailer': 42,
#  'in fortnite': 41,
#  'ft lil': 40,
#  '10 000': 40,
#  'to be': 39,
#  'premier league': 39,
#  '100 days': 38,
#  'mod in': 38,
#  'to my': 38,
#  'my new': 37,
#  'manchester united': 37,
#  'espn fc': 37,
#  'thee stallion': 36,
#  'teaser trailer': 36,
#  'the kid': 36,
#  'dream smp': 36,
#  'not to': 36,
#  'megan thee': 35,
#  'the weeknd': 35,
#  'remix official': 35,
#  'doja cat': 35,
#  'squid game': 35,
#  'easter eggs': 35,
#  'you can': 34,
#  '12 pro': 34,
#  'feat lil': 34,
#  'highlights 2021': 34,
#  'gender reveal': 34,
#  'myke towers': 33,
#  '000 000': 33,
#  'if you': 33,
#  'hardcore minecraft': 33,
#  'iphone 13': 33,
#  'first look': 33,
#  'press conference': 33,
#  'in my': 33,
#  'hot ones': 33,
#  'game theory': 33,
#  'call of': 33,
#  'of duty': 33,
#  'stray kids': 32,
#  "the world's": 32,
#  'with my': 32,
#  'genshin impact': 32,
#  'league highlights': 32,
#  'highlights september': 32,
#  'episode breakdown': 32,
#  'nba 2k22': 32,
#  'real life': 31,
#  'pooh shiesty': 31,
#  'season official': 31,
#  'things you': 31,
#  'reacting to': 31,
#  "here's what": 31,
#  'the end': 30,
#  'to make': 30,
#  'conor mcgregor': 30,
#  'ios 14': 30,
#  'cold war': 30,
#  'food theory': 30,
#  'fortnite season': 30,
#  'you missed': 30,
#  'tokyo olympics': 30,
#  'but every': 29,
#  'need to': 29,
#  'is here': 29,
#  'my friends': 29,
#  'house tour': 29,
#  'try not': 29,
#  'nintendo switch': 29,
#  'at lakers': 29,
#  'stephen reacts': 29,
#  'nba on': 29,
#  'ending explained': 29,
#  'olivia rodrigo': 28,
#  'welcome to': 28,
#  'best friend': 28,
#  'the 2021': 28,
#  'when you': 28,
#  'my first': 28,
#  'gameplay trailer': 28,
#  'hermitcraft episode': 28,
#  'film theory': 28,
#  'selena gomez': 27,
#  'trailer hd': 27,
#  'miley cyrus': 27,
#  '100 000': 27,
#  'every day': 27,
#  'tik tok': 27,
#  'to see': 27,
#  'year old': 27,
#  'of my': 27,
#  'lakers full': 27,
#  'on tnt': 27,
#  'official mv': 26,
#  'live performance': 26,
#  'but you': 26,
#  'for 24': 26,
#  'xbox series': 26,
#  'wings hot': 26,
#  'days in': 26,
#  'nba undisputed': 26,
#  'ice cream': 25,
#  'music awards': 25,
#  'taylor swift': 25,
#  'and more': 25,
#  "dixie d'amelio": 25,
#  'the truth': 25,
#  'with babish': 25,
#  'spicy wings': 25,
#  'minecraft hardcore': 25,
#  'what really': 25,
#  'highlights espn': 25,
#  'dead by': 25,
#  'by daylight': 25,
#  'me official': 24,
#  'marvel studios': 24,
#  'kid laroi': 24,
#  'king von': 24,
#  'audio ft': 24,
#  'grand prix': 24,
#  'my life': 24,
#  'moneybagg yo': 24,
#  'you official': 24,
#  'machine gun': 24,
#  'gun kelly': 24,
#  'the voice': 24,
#  'zhc crafts': 24,
#  'in hardcore': 24,
#  'the worst': 24,
#  'trailer reaction': 24,
#  'spider man': 23,
#  'jack harlow': 23,
#  'joe biden': 23,
#  'into the': 23,
#  'in real': 23,
#  'lil tjay': 23,
#  'binging with': 23,
#  'grupo firme': 23,
#  'battle royale': 23,
#  'at ufc': 23,
#  '42 dugg': 23,
#  'pbc on': 23,
#  'lakers at': 23,
#  'star wars': 23,
#  'to get': 23,
#  'to laugh': 23,
#  'clash of': 22,
#  'of clans': 22,
#  'my best': 22,
#  'young thug': 22,
#  'to know': 22,
#  'dancing with': 22,
#  'new season': 22,
#  'never broke': 22,
#  'broke again': 22,
#  'the ultimate': 22,
#  'met gala': 22,
#  'trippie redd': 22,
#  'can you': 22,
#  'dustin poirier': 22,
#  'while eating': 22,
#  'announcement trailer': 22,
#  'tyron woodley': 22,
#  'olympics nbc': 22,
#  'loss to': 22,
#  'israel adesanya': 22,
#  'easter egg': 22,
#  'us but': 21,
#  'super bowl': 21,
#  'to win': 21,
#  'el alfa': 21,
#  'floyd mayweather': 21,
#  'durk official': 21,
#  'inside the': 21,
#  'role in': 21,
#  'to me': 21,
#  'on fox': 21,
#  'paul vs': 21,
#  'the 2020': 21,
#  "i'm pregnant": 21,
#  'try guys': 21,
#  'is it': 21,
#  'highlights august': 21,
#  'the nba': 21,
#  'with complex': 21,
#  'laugh challenge': 21,
#  'skip shannon': 21,
#  'remix video': 20,
#  'rauw alejandro': 20,
#  'cold open': 20,
#  'is back': 20,
#  'trailer disney': 20,
#  'lil wayne': 20,
#  'trailer netflix': 20,
#  'nba youngboy': 20,
#  'guide to': 20,
#  'my dog': 20,
#  'eating spicy': 20,
#  'season trailer': 20,
#  'black ops': 20,
#  'ops cold': 20,
#  'nfl 2021': 20,
#  'nba finals': 20,
#  'september 2020': 20,
#  'euro 2020': 20,
#  'van halen': 20,
#  'sneaker shopping': 20,
#  'shopping with': 20,
#  'movie review': 20,
#  'baby official': 19,
#  'got talent': 19,
#  'survived 100': 19,
#  'youngboy never': 19,
#  'rick and': 19,
#  'new house': 19,
#  'the life': 19,
#  'you need': 19,
#  'roman reigns': 19,
#  'duty black': 19,
#  'highlights june': 19,
#  'smarter every': 19,
#  'the game': 19,
#  'highlights december': 19,
#  'first day': 19,
#  'reaction to': 19,
#  '2020 nbc': 19,
#  'merrell twins': 19,
#  'wandavision episode': 19,
#  'resumen goles': 19,
#  'on my': 18,
#  'live at': 18,
#  'tonight show': 18,
#  'sports hq': 18,
#  'cyberpunk 2077': 18,
#  'travis scott': 18,
#  'the legend': 18,
#  'legend of': 18,
#  'and morty': 18,
#  'if they': 18,
#  'clash royale': 18,
#  'trying to': 18,
#  'fredo bang': 18,
#  'tik toks': 18,
#  'paris saint': 18,
#  'saint germain': 18,
#  'real madrid': 18,
#  'champions league': 18,
#  'we are': 18,
#  'top 10': 18,
#  'bein sports': 18,
#  'sports usa': 18,
#  'goes sneaker': 18,
#  'season episode': 18,
#  'honest trailers': 18,
#  'starlink mission': 18,
#  'oddly satisfying': 17,
#  'bad bunny': 17,
#  'dance practice': 17,
#  'ateez 에이티즈': 17,
#  'hbo max': 17,
#  'logan paul': 17,
#  'official reveal': 17,
#  'league of': 17,
#  'of legends': 17,
#  'to beat': 17,
#  'look at': 17,
#  'bbc news': 17,
#  "charli d'amelio": 17,
#  'see if': 17,
#  'serie tim': 17,
#  'end of': 17,
#  'the mandalorian': 17,
#  'the last': 17,
#  'minecraft live': 17,
#  'the real': 17,
#  'about the': 17,
#  'day in': 17,
#  'when the': 17,
#  'be like': 17,
#  'day of': 17,
#  'lil tecca': 17,
#  'finding out': 17,
#  'post fight': 17,
#  'death battle': 17,
#  'eddie van': 17,
#  'breakdown ending': 17,
#  'sec shorts': 17,
#  'in game': 16,
#  'donald trump': 16,
#  'up official': 16,
#  'by the': 16,
#  'dua lipa': 16,
#  'the tonight': 16,
#  'jimmy fallon': 16,
#  'every turn': 16,
#  'prince harry': 16,
#  'truth about': 16,
#  'jay wheeler': 16,
#  'tiny desk': 16,
#  'desk home': 16,
#  'home concert': 16,
#  'demi lovato': 16,
#  'rod wave': 16,
#  'addison rae': 16,
#  'noah beck': 16,
#  'mike tyson': 16,
#  'what if': 16,
#  'life hacks': 16,
#  'the internet': 16,
#  'official live': 16,
#  'happened to': 16,
#  'all the': 16,
#  'rochy rd': 16,
#  'battle pass': 16,
#  'you have': 16,
#  'ufc 257': 16,
#  'smash bros': 16,
#  'days as': 16,
#  'wins 000': 16,
#  'extra scenes': 16,
#  'theory the': 16,
#  'tribute to': 16,
#  'slow mo': 16,
#  'xxl freshman': 16,
#  'really happened': 16,
#  'taste test': 16,
#  'bayern munich': 16,
#  'match highlights': 16,
#  'scott the': 16,
#  '10 things': 16,
#  '2021 bein': 16,
#  'loki episode': 16,
#  'the lakers': 16,
#  'item shop': 16,
#  'shawn mendes': 15,
#  "america's got": 15,
#  'turn different': 15,
#  'txt 투모로우바이투게더': 15,
#  'launch trailer': 15,
#  'each other': 15,
#  'our first': 15,
#  'love you': 15,
#  'in gta': 15,
#  'adult swim': 15,
#  'time to': 15,
#  'full episode': 15,
#  '21 savage': 15,
#  'del rey': 15,
#  'the next': 15,
#  'juice wrld': 15,
#  'pop smoke': 15,
#  'tyson fury': 15,
#  'ufc 264': 15,
#  'barcelona vs': 15,
#  "why don't": 15,
#  'showtime ppv': 15,
#  'broke up': 15,
#  'vs the': 15,
#  '000 challenge': 15,
#  'challenge zhc': 15,
#  'man city': 15,
#  'minecraft manhunt': 15,
#  'gucci mane': 15,
#  'pro max': 15,
#  'president trump': 15,
#  'new york': 15,
#  'the try': 15,
#  'is not': 15,
#  'embedded vlog': 15,
#  'vlog series': 15,
#  'series episode': 15,
#  'quando rondo': 15,
#  'nba playoffs': 15,
#  'breakdown easter': 15,
#  'win over': 15,
#  'morgan wallen': 15,
#  'laliga highlights': 15,
#  'lebron james': 15,
#  'the woz': 15,
#  'spoiler review': 15,
#  'fortnite battle': 15,
#  'fortnite item': 15,
#  'permission to': 14,
#  'to dance': 14,
#  'big game': 14,
#  'way home': 14,
#  'justice league': 14,
#  'than ever': 14,
#  'minecraft shorts': 14,
#  'best friends': 14,
#  'there are': 14,
#  'snoop dogg': 14,
#  'live on': 14,
#  'chadwick boseman': 14,
#  'they work': 14,
#  'this video': 14,
#  'my girlfriend': 14,
#  'nle choppa': 14,
#  'performance vevo': 14,
#  'life of': 14,
#  'sneak peek': 14,
#  'los dos': 14,
#  'drag race': 14,
#  'meek mill': 14,
#  'rocket league': 14,
#  'to watch': 14,
#  'to say': 14,
#  'deontay wilder': 14,
#  'the year': 14,
#  'we broke': 14,
#  'monster hunter': 14,
#  'covid 19': 14,
#  'highlights october': 14,
#  'young dolph': 14,
#  'fight press': 14,
#  "when you're": 14,
#  'with me': 14,
#  'trail blazers': 14,
#  'voice blind': 14,
#  'blind auditions': 14,
#  'the stars': 14,
#  'ufc 253': 14,
#  'minecraft 17': 14,
#  'highlights goals': 14,
#  "we're pregnant": 14,
#  'highlights 10': 14,
#  'you suck': 14,
#  'suck at': 14,
#  'at cooking': 14,
#  'cooking episode': 14,
#  '2021 fortnite': 14,
#  '방탄소년단 dynamite': 13,
#  'satisfying video': 13,
#  'call me': 13,
#  'no way': 13,
#  'on youtube': 13,
#  'godzilla vs': 13,
#  'vs kong': 13,
#  'anuel aa': 13,
#  'last to': 13,
#  'bought the': 13,
#  'daddy yankee': 13,
#  'apple watch': 13,
#  'open snl': 13,
#  'final trailer': 13,
#  'prime video': 13,
#  'trailer hbo': 13,
#  'tory lanez': 13,
#  'show starring': 13,
#  'starring jimmy': 13,
#  'is used': 13,
#  'for my': 13,
#  'it official': 13,
#  'but there': 13,
#  '13 pro': 13,
#  'to die': 13,
#  'in an': 13,
#  'mod is': 13,
#  'hacks to': 13,
#  'like that': 13,
#  'baby lil': 13,
#  'ryan garcia': 13,
#  'us song': 13,
#  'chris brown': 13,
#  'back to': 13,
#  'race highlights': 13,
#  'dos carnales': 13,
#  'slow motion': 13,
#  'official gameplay': 13,
#  'video game': 13,
#  'face off': 13,
#  'big sean': 13,
#  'pov you': 13,
#  'have to': 13,
#  'my dream': 13,
#  'how the': 13,
#  'insane craft': 13,
#  'highlights january': 13,
#  "and here's": 13,
#  'the slow': 13,
#  'mo guys': 13,
#  'live event': 13,
#  'bucks at': 13,
#  'to play': 13,
#  'for you': 13,
#  'lionel messi': 13,
#  '2020 nba': 13,
#  'responds to': 13,
#  'gabby petito': 13,
#  'telling my': 13,
#  'war warzone': 13,
#  'in nba': 13,
#  'hurricane ida': 13,
#  'nba 2k21': 13,
#  "louie's life": 13,
#  'dana white': 13,
#  'shannon react': 13,
#  'explained spoiler': 13,
#  'thailand open': 13,
#  'open day': 13,
#  'me by': 12,
#  'jhay cortez': 12,
#  'to leave': 12,
#  'leave the': 12,
#  "you can't": 12,
#  'game of': 12,
#  'brawl stars': 12,
#  'world record': 12,
#  'bowl lv': 12,
#  'grammys 2021': 12,
#  'talent 2021': 12,
#  'space jam': 12,
#  'kamala harris': 12,
#  'you know': 12,
#  'happier than': 12,
#  'lo er': 12,
#  'enhypen 엔하이픈': 12,
#  'game in': 12,
#  'canelo alvarez': 12,
#  'cartoon animation': 12,
#  'funkin but': 12,
#  'the 63rd': 12,
#  'fortnite chapter': 12,
#  'chapter season': 12,
#  'directed by': 12,
#  'mandalorian season': 12,
#  'types of': 12,
#  'awards 2020': 12,
#  'est gee': 12,
#  'kodak black': 12,
#  'with his': 12,
#  'people on': 12,
#  'people who': 12,
#  'john oliver': 12,
#  'most oddly': 12,
#  'the dark': 12,
#  'ready for': 12,
#  'tom macdonald': 12,
#  'happened at': 12,
#  'vs dustin': 12,
#  'it up': 12,
#  'state of': 12,
#  'legends season': 12,
#  'off the': 12,
#  'james harden': 12,
#  'our baby': 12,
#  'apple tv': 12,
#  'beat the': 12,
#  'breaks down': 12,
#  'dream minecraft': 12,
#  'uncle roger': 12,
#  'one of': 12,
#  'manchester city': 12,
#  'bretman rock': 12,
#  'super smash': 12,
#  'buccaneers vs': 12,
#  'surprising my': 12,
#  'to do': 12,
#  'bailey sarian': 12,
#  '2021 nfl': 12,
#  'at home': 12,
#  'at nets': 12,
#  'nets full': 12,
#  'up to': 12,
#  'kevin gates': 12,
#  '2021 nba': 12,
#  'queen naija': 12,
#  'trailer nintendo': 12,
#  'highlights february': 12,
#  'sports golazo': 12,
#  'national convention': 12,
#  'my boyfriend': 12,
#  'the sims': 12,
#  'crossfit games': 12,
#  'high school': 12,
#  'ufc 266': 12,
#  'every easter': 12,
#  'bad great': 12,
#  'rainbow six': 12,
#  'lil yachty': 12,
#  "grey's anatomy": 12,
#  'win vs': 12,
#  'scp animation': 12,
#  'shop new': 12,
#  'aespa 에스파': 11,
#  'the morning': 11,
#  'out official': 11,
#  'dj khaled': 11,
#  'nicky jam': 11,
#  'billboard music': 11,
#  'pay for': 11,
#  'harry styles': 11,
#  'guess the': 11,
#  'natti natasha': 11,
#  'us in': 11,
#  'funkin animation': 11,
#  'khabib nurmagomedov': 11,
#  'the batman': 11,
#  'the devil': 11,
#  'battlefield 2042': 11,
#  'are custom': 11,
#  'ready to': 11,
#  'us logic': 11,
#  'show with': 11,
#  'nicki minaj': 11,
#  'different skin': 11,
#  'skin mod': 11,
#  '63rd grammys': 11,
#  'airpods max': 11,
#  'by cole': 11,
#  'cole bennett': 11,
#  'the live': 11,
#  'over the': 11,
#  'trailer paramount': 11,
#  'my mom': 11,
#  'are you': 11,
#  'post malone': 11,
#  'be original': 11,
#  'gave me': 11,
#  'the day': 11,
#  'lil uzi': 11,
#  'uzi vert': 11,
#  'gone wrong': 11,
#  'resident evil': 11,
#  'toks that': 11,
#  'don toliver': 11,
#  'that will': 11,
#  'never seen': 11,
#  'with john': 11,
#  'video to': 11,
#  'mcgregor vs': 11,
#  'the final': 11,
#  'live 2021': 11,
#  'galaxy s21': 11,
#  "don't we": 11,
#  'than you': 11,
#  'the fortnite': 11,
#  'art wins': 11,
#  'had to': 11,
#  'my hair': 11,
#  'highlights may': 11,
#  'kanye west': 11,
#  'bros ultimate': 11,
#  'feat polo': 11,
#  '2020 xxl': 11,
#  'how many': 11,
#  'ken block': 11,
#  'simone biles': 11,
#  '11 2020': 11,
#  'carabao cup': 11,
#  'me to': 11,
#  'collection reveal': 11,
#  'heat at': 11,
#  'mystery makeup': 11,
#  'makeup bailey': 11,
#  'weigh in': 11,
#  'game nba': 11,
#  'my house': 11,
#  'at clippers': 11,
#  'clippers full': 11,
#  'wrong with': 11,
#  'me on': 11,
#  'faze clan': 11,
#  'key glock': 11,
#  'paulo costa': 11,
#  'details you': 11,
#  '27 2020': 11,
#  'great cgi': 11,
#  'wit da': 11,
#  'made the': 11,
#  'six siege': 11,
#  '2020 crossfit': 11,
#  '2021 nbc': 11,
#  'first impressions': 11,
#  'final fantasy': 11,
#  'yonex thailand': 11,
#  'goes on': 10,
#  'lovesick girls': 10,
#  'the ground': 10,
#  'nas montero': 10,
#  'your name': 10,
#  "can't stop": 10,
#  'stop me': 10,
#  'man no': 10,
#  'on me': 10,
#  'save your': 10,
#  'tom brady': 10,
#  "world's largest": 10,
#  'anderson paak': 10,
#  'brawl talk': 10,
#  'official visualizer': 10,
#  '이달의 소녀': 10,
#  'remix feat': 10,
#  'alfa el': 10,
#  'days of': 10,
#  'james charles': 10,
#  'do it': 10,
#  'with custom': 10,
#  'the dream': 10,
#  'the dixie': 10,
#  "d'amelio show": 10,
#  'helluva boss': 10,
#  'mini crewmate': 10,
#  'all time': 10,
#  'roy jones': 10,
#  'jones jr': 10,
#  'you think': 10,
#  'but if': 10,
#  'suez canal': 10,
#  "i've been": 10,
#  'love official': 10,
#  'in theaters': 10,
#  'on another': 10,
#  'another level': 10,
#  'white house': 10,
#  'last week': 10,
#  'week tonight': 10,
#  'you escape': 10,
#  'watch before': 10,
#  'the big': 10,
#  'name reveal': 10,
#  'return to': 10,
#  'full fight': 10,
#  'fury vs': 10,
#  'samsung galaxy': 10,
#  'things that': 10,
#  'the funniest': 10,
#  'de la': 10,
#  'e3 2021': 10,
#  'music bank': 10,
#  'joyner lucas': 10,
#  'city girls': 10,
#  'suicide squad': 10,
#  'for me': 10,
#  'fivio foreign': 10,
#  'birthday party': 10,
#  'vs cowboys': 10,
#  'cowboys week': 10,
#  'gta online': 10,
#  'in your': 10,
#  'in 24': 10,
#  'we re': 10,
#  'speed and': 10,
#  'what found': 10,
#  'what happens': 10,
#  'rylo rodriguez': 10,
#  'united premier': 10,
#  'tell you': 10,
#  'the cast': 10,
#  'interview with': 10,
#  'is what': 10,
#  'the future': 10,
#  'up with': 10,
#  'kim kardashian': 10,
#  'happens when': 10,
#  'las vegas': 10,
#  'espn mma': 10,
#  'at suns': 10,
#  'at heat': 10,
#  'heat full': 10,
#  'do this': 10,
#  'nate robinson': 10,
#  'when your': 10,
#  'at bucks': 10,
#  'bucks full': 10,
#  'to jake': 10,
#  'lamelo ball': 10,
#  'los angeles': 10,
#  'arrested in': 10,
#  "can't live": 10,
#  'live without': 10,
#  'without gq': 10,
#  'doctor reacts': 10,
#  'true facts': 10,
#  'dw news': 10,
#  'hall of': 10,
#  'of fame': 10,
#  'yungeen ace': 10,
#  '16 highlights': 10,
#  'vfx artists': 10,
#  'artists react': 10,
#  'to bad': 10,
#  'boogie wit': 10,
#  'da hoodie': 10,
#  '21 mlb': 10,
#  'mlb highlights': 10,
#  'vs barcelona': 10,
#  'of our': 10,
#  'pat mcafee': 10,
#  "sean o'malley": 10,
#  'review marvel': 10,
#  'destiny beyond': 10,
#  'beyond light': 10,
#  'hermitcraft s8': 10,
#  'ufc 252': 10,
#  'the bachelorette': 10,
#  'night smackdown': 10,
#  'best build': 10,
#  '방탄소년단 butter': 9,
#  'dynamite official': 9,
#  '2020 election': 9,
#  'drivers license': 9,
#  '2020 21': 9,
#  'silk sonic': 9,
#  'would you': 9,
#  '2021 official': 9,
#  'stars brawl': 9,
#  '소녀 loona': 9,
#  'ed sheeran': 9,
#  'with this': 9,
#  'first to': 9,
#  'and first': 9,
#  'original song': 9,
#  'deja vu': 9,
#  'do you': 9,
#  'watch series': 9,
#  'vanity fair': 9,
#  'trailer prime': 9,
#  'el jefe': 9,
#  '마마무 mamamoo': 9,
#  'ufc 254': 9,
#  'dc fandome': 9,
#  'sings it': 9,
#  'bryant myers': 9,
#  'was like': 9,
#  'jennifer lopez': 9,
#  'is this': 9,
#  'kylie jenner': 9,
#  'trailer 2021': 9,
#  '2021 movie': 9,
#  'back in': 9,
#  'little mix': 9,
#  'trailer ps5': 9,
#  'dude perfect': 9,
#  'harry and': 9,
#  'you lose': 9,
#  'live lounge': 9,
#  'you beat': 9,
#  'trailer the': 9,
#  'jhené aiko': 9,
#  'on released': 9,
#  'for week': 9,
#  'fight highlights': 9,
#  'want to': 9,
#  'season battle': 9,
#  'your life': 9,
#  'super mario': 9,
#  'my husband': 9,
#  'beauty secrets': 9,
#  'for day': 9,
#  'ty dolla': 9,
#  'dolla ign': 9,
#  'awards 2021': 9,
#  'around the': 9,
#  'tonight with': 9,
#  'freestyle official': 9,
#  'imposter role': 9,
#  'viral tiktok': 9,
#  'on earth': 9,
#  'story of': 9,
#  'you get': 9,
#  'kbs world': 9,
#  'world tv': 9,
#  'vs deontay': 9,
#  '60 minutes': 9,
#  'story trailer': 9,
#  's21 ultra': 9,
#  'to our': 9,
#  'went to': 9,
#  'gervonta davis': 9,
#  'on showtime': 9,
#  '2020 playoffs': 9,
#  'open door': 9,
#  'architectural digest': 9,
#  'dhar mann': 9,
#  'in miami': 9,
#  'spent day': 9,
#  'day with': 9,
#  'the biggest': 9,
#  'but the': 9,
#  'our new': 9,
#  'better than': 9,
#  'saying goodbye': 9,
#  'highlights spurs': 9,
#  'qualifying highlights': 9,
#  'next gen': 9,
#  'feat pooh': 9,
#  'shiesty official': 9,
#  'we have': 9,
#  'how does': 9,
#  'ways to': 9,
#  'no sense': 9,
#  'returns to': 9,
#  'attack on': 9,
#  'in 25x': 9,
#  '25x speed': 9,
#  'thank you': 9,
#  'luke combs': 9,
#  'clippers at': 9,
#  'the boys': 9,
#  'in new': 9,
#  'jeffree star': 9,
#  "didn't know": 9,
#  'without recipe': 9,
#  'santa cruz': 9,
#  'nuggets at': 9,
#  'nba preseason': 9,
#  'vs seahawks': 9,
#  'suns full': 9,
#  'highlights july': 9,
#  'dragon ball': 9,
#  'did the': 9,
#  'first ever': 9,
#  'busta rhymes': 9,
#  'nets at': 9,
#  'trailer breakdown': 9,
#  'funkin mod': 9,
#  'us open': 9,
#  'know about': 9,
#  'kabul airport': 9,
#  'death of': 9,
#  'got my': 9,
#  'to face': 9,
#  'faze rug': 9,
#  'ben askren': 9,
#  'immediate reaction': 9,
#  'make the': 9,
#  'meet the': 9,
#  'rich the': 9,
#  'exclusive look': 9,
#  'total war': 9,
#  'tier list': 9,
#  'at celtics': 9,
#  'celtics full': 9,
#  'it was': 9,
#  ...}

# %%
plot_word_freq(two_words, 25, 'Most Common 2-word Phrases', 'common_2words.png')

# %%
# most common 3-word phrases in titles
three_words = print_dict_sort(title_analysis(final['title'], 3), True)
#three_words

# %%
plot_word_freq(three_words, 25, 'Most Common 3-word Phrases', 'common_3words.png')

# %%
# most common 4-word phrases in titles
four_words = print_dict_sort(title_analysis(final['title'], 4), True)
#four_words

# %%
plot_word_freq(four_words, 25, 'Most Common 4-word Phrases', 'common_4words.png')
